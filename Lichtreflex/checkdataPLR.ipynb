# %%
# !pip install pyplr
# !pip install neurokit2
import sys
sys.path.append("../Pupillengröße/Skripte/")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import logging as log
from preprocessfunction2 import PLR2d
from preprocessfunction3 import PLR3d
import checkdataPLR
import importlib
from IPython.display import display
def display_all(df):
    from IPython.display import HTML, display
    IPython.display(IPython.HTML(df.to_html()))
# Out:
# Requirement already satisfied: pyplr in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (1.0.3)
# Requirement already satisfied: numexpr in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (2.8.4)
# Requirement already satisfied: seabreeze in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (2.3.0)
# Requirement already satisfied: pandas in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (2.0.1)
# Requirement already satisfied: pyzmq in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (25.0.2)
# Requirement already satisfied: msgpack in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (1.0.5)
# Requirement already satisfied: scipy in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (1.10.1)
# Requirement already satisfied: matplotlib in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (3.7.1)
# Requirement already satisfied: numpy in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (1.24.3)
# Requirement already satisfied: requests in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (2.30.0)
# Requirement already satisfied: seaborn in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (0.12.2)
# Requirement already satisfied: tables in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pyplr) (3.8.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (4.39.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->pyplr) (9.5.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pandas->pyplr) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pandas->pyplr) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from requests->pyplr) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from requests->pyplr) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from requests->pyplr) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from requests->pyplr) (2.0.2)
# Requirement already satisfied: py-cpuinfo in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from tables->pyplr) (9.0.0)
# Requirement already satisfied: cython>=0.29.21 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from tables->pyplr) (0.29.34)
# Requirement already satisfied: blosc2~=2.0.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from tables->pyplr) (2.0.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->pyplr) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->pyplr) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/Katharina/Pupille/venv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: neurokit2 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: scipy in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from neurokit2) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from neurokit2) (1.2.2)
# Requirement already satisfied: pandas in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from neurokit2) (2.0.1)
# Requirement already satisfied: numpy in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from neurokit2) (1.24.3)
# Requirement already satisfied: matplotlib in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from neurokit2) (3.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from scikit-learn>=1.0.0->neurokit2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from scikit-learn>=1.0.0->neurokit2) (3.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (4.39.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib->neurokit2) (0.11.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pandas->neurokit2) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pandas->neurokit2) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->neurokit2) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->neurokit2) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/Katharina/Pupille/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
# wenn ich checkpadata.py ändere, muß das Modul neu importiert werden. Das macht reload()
importlib.reload(checkdataPLR)
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams['figure.dpi'] = 200 
subject_id="PJ03_1_PLR1"
data_dir="/Users/Katharina/Desktop/Beispieldaten"
#data_dir="../data/groesse/3.4Stimulation/"
config=checkdataPLR.DataConfig(window_duration=150)
eye0=checkdataPLR.prepare(data_dir,subject_id,0,config)
eye1=checkdataPLR.prepare(data_dir,subject_id,1,config)
checkdataPLR.plot(eye0[0],"auge 0 (0)")
display(eye0[0])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 2
#       1 # wenn ich checkpadata.py ändere, muß das Modul neu importiert werden. Das macht reload()
# ----> 2 importlib.reload(checkdataPLR)
#       3 plt.rcParams['figure.figsize'] = [20, 10]
#       4 plt.rcParams['figure.dpi'] = 200
#
# File ~/opt/anaconda3/lib/python3.9/importlib/__init__.py:169, in reload(module)
#     167 if spec is None:
#     168     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 169 _bootstrap._exec(spec, module)
#     170 # The module may have replaced itself in sys.modules!
#     171 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:613, in _exec(spec, module)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Pupille/Lichtreflex/checkdataPLR.py:5
#       3 import matplotlib.pyplot as plt
#       4 import logging as log
# ----> 5 from dataclasses import dataclassPLR
#       7 @dataclassPLR
#       8 class DataConfig:
#       9     window_duration:float=14
#
# ImportError: cannot import name 'dataclassPLR' from 'dataclasses' (/Users/Katharina/opt/anaconda3/lib/python3.9/dataclasses.py)

# %% [markdown]
# ### Use datamatrix from pydatamatrix.eu to fill in blinking gaps

# %%
# !pip install fastnumbers
# !pip install datamatrix
import datamatrix
import datamatrix.series
import datamatrix.operations
# Out:
# Requirement already satisfied: fastnumbers in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (5.0.1)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/Katharina/Pupille/venv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: datamatrix in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (1.0.2)
# Requirement already satisfied: tomlkit in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from datamatrix) (0.11.8)
# Requirement already satisfied: openpyxl in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from datamatrix) (3.1.2)
# Requirement already satisfied: prettytable in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from datamatrix) (3.7.0)
# Requirement already satisfied: json-tricks in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from datamatrix) (3.16.1)
# Requirement already satisfied: psutil in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from datamatrix) (5.9.5)
# Requirement already satisfied: scipy in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from datamatrix) (1.10.1)
# Requirement already satisfied: numpy in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from datamatrix) (1.24.3)
# Requirement already satisfied: et-xmlfile in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from openpyxl->datamatrix) (1.1.0)
# Requirement already satisfied: wcwidth in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from prettytable->datamatrix) (0.2.6)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/Katharina/Pupille/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
dm_eye0_diameter=datamatrix.convert.from_pandas(eye0[0])['diameter']
plt.plot(dm_eye0_diameter)

# %%
dm_eye0_diameter_fixed=datamatrix.series.blinkreconstruct(dm_eye0_diameter, mode='advanced')
plt.plot(dm_eye0_diameter_fixed)

# %%
import preprocessingCopy1

# %%
import tkinter
