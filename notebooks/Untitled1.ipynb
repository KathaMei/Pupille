# %%
import pickle
import numpy as np
with open("/Users/Katharina/Desktop/ErgebnissePreprocessing/PJ01_1_Ruhe_diameter_0.pickle", "rb") as file:
    data = pickle.load(file)
    data_np = np.array(data, allow_pickle=True)
display(data_np)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       3 with open("/Users/Katharina/Desktop/ErgebnissePreprocessing/PJ01_1_Ruhe_diameter_0.pickle", "rb") as file:
#       4     data = pickle.load(file)
# ----> 5     data_np = np.array(data, allow_pickle=True)
#       6 display(data_np)
#
# TypeError: array() got an unexpected keyword argument 'allow_pickle'

# %%
np.save("/Users/Katharina/Desktop/ErgebnissePreprocessing/PJ01_1_Ruhe_diameter_0.npy", data_np)

# %%
np.savetxt("/Users/Katharina/Desktop/ErgebnissePreprocessing/PJ01_1_Ruhe_diameter_0.csv", data_np, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 np.savetxt("/Users/Katharina/Desktop/ErgebnissePreprocessing/PJ01_1_Ruhe_diameter_0.csv", data_np, delimiter=",")
#
# File <__array_function__ internals>:200, in savetxt(*args, **kwargs)
#
# File ~/Desktop/Pupille/venv/lib/python3.9/site-packages/numpy/lib/npyio.py:1555, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1553 # Handle 1-dimensional arrays
#    1554 if X.ndim == 0 or X.ndim > 2:
# -> 1555     raise ValueError(
#    1556         "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1557 elif X.ndim == 1:
#    1558     # Common case -- 1d array of numbers
#    1559     if X.dtype.names is None:
#
# ValueError: Expected 1D or 2D array, got 0D array instead

# %%
print(data_np)
# Out:
# ProcessResult(config=ProcessConfig(eyenum=0, column='diameter', sfactor=1, data_path='/Users/Katharina/Desktop/Beispieldaten', subject_id='PJ01_1_Ruhe', condition='3.4Placebo', timebase='3.4', stime_time_offset=0, after_var_start_offset=25.5, window_duration=29, nan_reconstruct_threshold=30, nan_before_threshold=0, nan_after_threshold=0, noise_threshold_factor=16, noise_rejection_percent=20, validate_only=False), num_valid=41, frames=[ProcessFrame(baseline_mean=87.15935646221402, baseline_std=1.829929266751441, annotation_ts=17893.205035, zscore=nan, valid=True, stage='finished', remark='', data=       pupil_timestamp  world_index  eye_id  confidence  norm_pos_x
# 384       17892.208390           24       0    0.930315    0.246212  \
# 385       17892.208390           24       0    0.930315    0.246396
# 388       17892.216450           24       0    0.858911    0.245543
# 389       17892.216450           24       0    0.858911    0.245926
# ...

# %%
print(data_np.shape)
# Out:
# ()
