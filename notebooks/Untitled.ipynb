# %%
# !pip install pandas matplotlib
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: matplotlib in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Users/Katharina/Pupille/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/Katharina/Pupille/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
data = pd.read_csv('/Users/Katharina/Desktop/Beispieldaten/PJ01_2_Ruhe_Stimulation_eye_id0_diameter_list.csv')
plt.plot(data['pupil_timestamp'], data['diameter_rec_interp_100'])
plt.xlabel('Pupil Timestamp')
plt.ylabel('Diameter Interp 100')
plt.title('Pupil Diameter over Time')
plt.show()
